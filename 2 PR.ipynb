# %%
import pandas as pd

# %%
Data1 = pd.read_csv('AcademicPerformance.csv')
print(Data1)
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04       NaN
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3      NaN          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father         15.0              16.0
# ...

# %%
Data1.shape
# Out:
# (480, 17)

# %%
Data1.isnull().sum()
# Out:
# gender                      10
# NationalITy                  0
# PlaceofBirth                 0
# StageID                      0
# GradeID                      0
# SectionID                    6
# Topic                        0
# Semester                     9
# Relation                     0
# raisedhands                 10
# VisITedResources             5
# AnnouncementsView            4
# Discussion                   0
# ParentAnsweringSurvey        0
# ParentschoolSatisfaction     0
# StudentAbsenceDays           0
# Class                        0
# dtype: int64

# %%
Data1.dropna(inplace=True)
print(Data1.isnull().sum())
# Out:
# gender                      0
# NationalITy                 0
# PlaceofBirth                0
# StageID                     0
# GradeID                     0
# SectionID                   0
# Topic                       0
# Semester                    0
# Relation                    0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
import pandas as pd
import numpy as np

# %%
Data2 = pd.read_csv('AcademicPerformance.csv')
print(Data2)
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04       NaN
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3      NaN          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father         15.0              16.0
# ...

# %%
Data2.notnull()
# Out:
#      gender  NationalITy  PlaceofBirth  StageID  GradeID  SectionID  Topic  \
# 0      True         True          True     True     True       True   True
# 1      True         True          True     True     True      False   True
# 2      True         True          True     True     True       True   True
# 3     False         True          True     True     True       True   True
# 4      True         True          True     True     True       True   True
# ..      ...          ...           ...      ...      ...        ...    ...
# 475    True         True          True     True     True       True   True
# 476    True         True          True     True     True       True   True
# 477    True         True          True     True     True       True   True
# 478    True         True          True     True     True       True   True
# 479    True         True          True     True     True       True   True
#
# ...

# %%
series1 = pd.notnull(Data2["raisedhands"])
Data2[series1]
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04       NaN
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3      NaN          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father         15.0              16.0
# ...

# %%
df=Data2
df.fillna(0)
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         0
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        0          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father         15.0              16.0
# ...

# %%
df['GradeID'].fillna('Grade')
# Out:
# 0      G-04
# 1      G-04
# 2      G-04
# 3      G-04
# 4      G-04
#        ...
# 475    G-08
# 476    G-08
# 477    G-08
# 478    G-08
# 479    G-08
# Name: GradeID, Length: 480, dtype: object

# %%
df[ 'VisITedResources'].fillna(df[ 'VisITedResources'].mean())
# Out:
# 0      16.0
# 1      20.0
# 2       7.0
# 3      25.0
# 4      50.0
#        ...
# 475     4.0
# 476    77.0
# 477    74.0
# 478    17.0
# 479    14.0
# Name: VisITedResources, Length: 480, dtype: float64

# %%
df[ 'VisITedResources'].fillna(df[ 'VisITedResources'].median())
# Out:
# 0      16.0
# 1      20.0
# 2       7.0
# 3      25.0
# 4      50.0
#        ...
# 475     4.0
# 476    77.0
# 477    74.0
# 478    17.0
# 479    14.0
# Name: VisITedResources, Length: 480, dtype: float64

# %%
df[ 'Class'].value_counts()
# Out:
# M    211
# H    142
# L    127
# Name: Class, dtype: int64

# %%
df['Class'].fillna(df['Class'].mode()[0])
# Out:
# 0      M
# 1      M
# 2      L
# 3      L
# 4      M
#       ..
# 475    L
# 476    M
# 477    M
# 478    L
# 479    L
# Name: Class, Length: 480, dtype: object

# %%
df.fillna(method="backfill")
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father         15.0              16.0
# ...

# %%
df.fillna(method="pad")
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father         15.0              16.0
# ...

# %%
df.describe()
# Out:
#        raisedhands  VisITedResources  AnnouncementsView  Discussion
# count   470.000000        475.000000         476.000000  480.000000
# mean     47.506383         55.374737          38.237395   43.283333
# std      30.483226         32.769213          26.493621   27.637735
# min       0.000000          0.000000           0.000000    1.000000
# 25%      17.000000         20.000000          15.000000   20.000000
# 50%      50.000000         66.000000          33.000000   39.000000
# 75%      75.000000         84.000000          58.000000   70.000000
# max     100.000000         99.000000          98.000000   99.000000
